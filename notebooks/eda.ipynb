# %%
import re
from pathlib import Path

# %%
import pandas as pd
pd.set_option('display.max_rows', 1000)  # 省略されないように表示件数を設定

# %%
DATA_DIR = Path('../data/')
files_path = list(DATA_DIR.joinpath('timetable_2023').glob('*.xlsx'))

# %%
dfs = {}
pattern = re.compile('[A-Z]')
for file_path in files_path:
    df = pd.read_excel(file_path, sheet_name=1)  # 0番目(X科)は時間割の神エクセル、1番目(Sheet1)がシラバス形式
    df['授業コード'] = df['授業コード'].astype(str).apply(lambda x: x.zfill(4))  # 授業コードは左ゼロ埋めで4桁
    df['ｺｰｽ'] = df['ｺｰｽ'].astype(str).apply(lambda x: x.strip())  # \u3000(全角スペース)が含まれているので除去
    df['学年'] = df['学年'].astype(str)  # 数値と文字列が混在しているので文字列に統一
    key = pattern.findall(str(file_path))[0]
    dfs[key] = df
df = dfs['M']
cols = df.columns

# %%
# 備考: 講義名前の「（特）」「（留）」は特別授業と留学生対象科目、講義名後に「（19生以前のみ）」などの特記事項あり
# 備考: ◎印-必修科目、□印-選択必修科目、○印-選択科目、△印-自由科目、■印(選択必修科目)-履修制限科目（同群の再履修者専用科目）
# 備考: ②-1・②-2等は自動的に学籍番号で分割され、1組・2組等はレベル別(履修登録前に発表される掲示で確認)
df.head()
# Out:
#   授業コード        授業科目 必選  コマ数      ｺｰｽ 学年  ｸﾗｽ  教員名  最大人数
# 0  0001     スタディスキル  ◎    1  M・F・E・T  1  ④-1  高橋明   NaN
# 1  0002     スタディスキル  ◎    1  M・F・E・T  1  ④-2   福山   NaN
# 2  0003     スタディスキル  ◎    1  M・F・E・T  1  ④-3   福山   NaN
# 3  0004     スタディスキル  ◎    1  M・F・E・T  1  ④-4   小林   NaN
# 4  0029  （特）スタディスキル  ◎    1  M・F・E・T  2  NaN  小田切   NaN

# %% [markdown]
# # 授業コード

# %%
# 単純な疑問: 授業コード0002と0003に関して、教員が同じため同じ講義と思われるのですが、授業コードが異なるのはなぜでしょうか？
df[:4]
# Out:
#   授業コード     授業科目 必選  コマ数      ｺｰｽ 学年  ｸﾗｽ  教員名  最大人数
# 0  0001  スタディスキル  ◎    1  M・F・E・T  1  ④-1  高橋明   NaN
# 1  0002  スタディスキル  ◎    1  M・F・E・T  1  ④-2   福山   NaN
# 2  0003  スタディスキル  ◎    1  M・F・E・T  1  ④-3   福山   NaN
# 3  0004  スタディスキル  ◎    1  M・F・E・T  1  ④-4   小林   NaN

# %% [markdown]
# # 必選
# 一応xcatが組む際には使わないと想定されるので、各々の意味はよくわからないが無視できる。

# %%
# ○: 選択科目であり、◎: 必修科目であるという矛盾が生じているように思えます。
# □: 選択必修科目との違いは何でしょうか？
df[503:507]
# Out:
#     授業コード  授業科目  必選  コマ数      ｺｰｽ   学年  ｸﾗｽ 教員名  最大人数
# 503  0505  英会話Ⅰ  ○◎    1  M・F・E・T  1・2  NaN  大木   NaN
# 504  0523  英会話Ⅰ  ○◎    1  M・F・E・T  1・2  NaN  大木   NaN
# 505  0520  英会話Ⅱ  ○◎    1  M・F・E・T  1・2  NaN  大木   NaN
# 506  0525  英会話Ⅱ  ○◎    1  M・F・E・T  1・2  NaN  大木   NaN

# %%
# また、■は選択必修科目かつ再履修者専用という位置づけでしょうか？
df[df['必選'] == '■']
# Out:
#     授業コード     授業科目 必選  コマ数  ｺｰｽ 学年  ｸﾗｽ  教員名  最大人数
# 407  8200  基礎力学Ⅰ-a  ■    1  M・F  1  NaN  佐藤航   NaN
# 412  8204  基礎力学Ⅱ-a  ■    1  M・F  2  NaN   南葉   NaN

# %%
# しかし、再履修前の科目(つまり同名の科目)は存在しません...
target_names = df[df['必選'] == '■']['授業科目'].tolist()
df[df['授業科目'].isin(target_names)]
# Out:
#     授業コード     授業科目 必選  コマ数  ｺｰｽ 学年  ｸﾗｽ  教員名  最大人数
# 407  8200  基礎力学Ⅰ-a  ■    1  M・F  1  NaN  佐藤航   NaN
# 412  8204  基礎力学Ⅱ-a  ■    1  M・F  2  NaN   南葉   NaN

# %% [markdown]
# # コース

# %%
# コースがない場合(nan)はどういった扱いになるのでしょうか？
df['ｺｰｽ'].unique()
# Out:
# array(['M・F・E・T', 'M・F・E', 'T', 'M・E', 'F', 'M・F・T', 'E', 'J', 'F・T',
#        'M・E・T', 'S', 'J・F・T', 'M', 'S・F', 'J・T', 'M・T', 'M・F', 'S・J・F・T',
#        'S・J', 'nan'], dtype=object)

# %% [markdown]
# # 学年

# %%
# 「1・2」と「1･2」が混在しているので処理の時には注意！
# TODO: 表記ゆれの除去
df['学年'].unique()
# Out:
# array(['1', '2', '1・2', '3', '1･2', '2・3', '4', '3・4'], dtype=object)

# %% [markdown]
# # クラス

# %%
# クラスがない場合(nan)はどういった扱いになるのでしょうか？
df['ｸﾗｽ'].unique()
# Out:
# array(['④-1', '④-2', '④-3', '④-4', nan, '②-1', '②-2', '1組', '2組', '3組',
#        '③-1', '③-2', '③-3'], dtype=object)

# %% [markdown]
# # 教員名

# %%
# ちょっと厄介なので処理の時に注意
df['教員名'].unique()
# Out:
# array(['高橋明', '福山', '小林', '小田切', '三浦', '中山', '石田', '上野', '楠',
#        '＊三浦・師玉真・佐藤史・多田・中畑・山田陽・山本崇',
#        '〔＊三浦〕\u3000師玉真・山本聡・佐藤史・小田切・山田陽・山本崇・中畑', 'ﾑﾙｱｶ', '〔＊師玉〕', '師玉真',
#        '＊師玉真・小田切', '＊伊藤勝・冨澤', '室井', '山本崇', '多田', '山本聡', '渡辺', '荒船', '佐々木',
#        '竹村', '趙', '中畑', '於保', '義澤', '山崎', '佐藤史', '鍋倉', '兼頭', '田辺', '比嘉',
#        '泉', 'ﾊｽｹﾞﾚﾙ', '三橋', '山田博', '山田陽', '高坂', '〔＊高嶋〕\u3000勝浦・松本剛',
#        '〔＊高嶋〕\u3000岩崎', '〔＊高嶋〕\u3000松本彰', '〔＊高嶋〕\u3000戸松', '浅川', '町田',
#        '宮城', '山本', '大木', '岩本', '大平', '天谷', '河野', '照井', '木村茂', '〔＊大木〕',
#        '新谷', 'Ｄ', '松下', '牛膓', '田口', '池川', '菊地', '小机', '神谷亮', '南葉', '兒玉',
#        '熊谷', '格和', '＊納富・高取・杉村・三枝亮・宮崎・村田・臼杵・鈴木聡・塩野・須藤・前田', '＊金井・広井・若杉・中尾',
#        '＊金井・瑞慶覧・前田', '〔＊斎藤〕', '師玉礼', '江連', '吉岡', '高橋一', '渡部', '＊照井・中根',
#        '今井', '萩野', '木村', '林', '佐藤智', '＊水野・丸山・小池', '川島', '吉川',
#        '＊今井・熊谷・長尾・髙村・酒井・高取', '有川', '＊今井・小机・渡部・萩野',
#        '＊川島・佐藤智・中根・林・渡部・熊谷・山中・Ａ', '＊川島・高石・木村茂・林・吉岡・吉川・根本・山中・大場・Ａ',
#        '＊照井・渡邉・稲谷・杉本・三桝・佐藤昌', '＊木村茂・渡邉・稲谷・杉本・三桝・佐藤昌', '大場', '＊林・M科全教員',
#        '高石', '＊川島・高石・有川・中根・渡部・水野・萩野', '高橋篤', '酒田', '山田', '＊中根・照井・栗田・田中',
#        '西澤', '＊照井・南部', '田嶋', '丸山', '木村南', '水野', '＊佐藤智・熊谷・萩野・木村南・小池',
#        '＊佐藤智・萩野・水野・吉川・熊谷・小池', '＊今井・有川・根本・吉岡', '＊水野・吉川', '＊林・吉岡・吉川',
#        '＊水野・中根', '＊照井・田中', '＊有川・今井・根本・吉岡', '＊林・中根・吉川', '中根', nan,
#        '＊林・佐藤智・熊谷・小池', '＊林', '＊小机', '＊中根', '瑞慶覧', '＊山本聡・宇田川', '野井', '鈴木芳',
#        '土谷', 'ﾗｻﾞﾌｨ', '米田', '吉田', '沼田', '谷戸', '後藤', '田鎖', '竹田', '藤森',
#        '佐藤航', ' 門田', '門田', '栗田', '高橋正', '関', '松村', '高須', '神谷',
#        '＊石綿・山本・池田・高須・渡辺・兒玉・押鐘・鵜川',
#        '〔＊石綿〕\u3000門田・格和・南葉・高須・渡辺・兒玉・押鐘・五十嵐・大益', '五十嵐', '藤村', '新井', '高橋典',
#        '＊山本聡・門田・田辺・佐藤史・神谷', '塩﨑', '毛利', '川崎', '松鹿', '山本明', '＊田辺・門田',
#        '＊田辺・山本聡・門田・佐藤史', '＊門田・吉野・三栖・兒玉・小池・千葉', '端山', '石塚', '吉野',
#        '＊今井・板子・齋藤・納富・塩川・河原崎・金井・飯田・原島', '＊今井・板子', '＊今井・齋藤・金井・飯田', '＊今井',
#        '＊板子・今井'], dtype=object)

# %%
# 以下の講義は担当教員がいない(nan)のですが、そのような講義は存在するのでしょうか？
df[df['教員名'].isnull()]
# Out:
#     授業コード                                  授業科目 必選  コマ数  ｺｰｽ 学年  ｸﾗｽ  教員名
# 352  1096                           機械工学プロジェクトⅡ  ◎    2  M・E  1  ②-1  NaN  \
# 355  1097                           機械工学プロジェクトⅡ  ◎    2  M・E  1  ②-2  NaN
# 507  1113  Academic English for Global Leader Ⅰ  ○    1    F  1  NaN  NaN
# 508  1115  Academic English for Global Leader Ⅲ  ○    1    F  2  NaN  NaN
# 509  1114  Academic English for Global Leader Ⅱ  ○    1    F  1  NaN  NaN
# 510  1116  Academic English for Global Leader Ⅳ  ○    1    F  2  NaN  NaN
#
#      最大人数
# 352   NaN
# 355   NaN
# 507   NaN
# 508   NaN
# 509   NaN
# 510   NaN

# %%
# 以下のような教員名の場合、講義の各回ごとに担当教員が異なるという認識でよろしいのでしょうか？
df[19:21]
# Out:
#    授業コード    授業科目 必選  コマ数    ｺｰｽ 学年  ｸﾗｽ                        教員名  最大人数
# 19  0070  現代社会講座  ◎    1  M・F・E  1  ②-1  ＊三浦・師玉真・佐藤史・多田・中畑・山田陽・山本崇   NaN
# 20  0071  現代社会講座  ◎    1  M・F・E  1  ②-2  ＊三浦・師玉真・佐藤史・多田・中畑・山田陽・山本崇   NaN

# %%
# 以下の講義は「代表者であるが授業は担当しない」表記ですが、どういう状態なのでしょうか？
exists_idx = df['教員名'].dropna().index
df_sub = df.iloc[exists_idx]

df_sub.loc[df_sub['教員名'].str.match('〔＊.*〕') & (df_sub['教員名'].apply(len) <= 5)]
# Out:
#     授業コード            授業科目 必選  コマ数      ｺｰｽ   学年  ｸﾗｽ    教員名  最大人数
# 23   0088       新聞理解表現演習Ⅰ  ◎    1        T    1  NaN  〔＊師玉〕   NaN
# 24   0089       新聞理解表現演習Ⅱ  ◎    1        T    1  NaN  〔＊師玉〕   NaN
# 180  0544          総合英語演習  ○    1  M・F・E・T    1  NaN  〔＊大木〕   NaN
# 181  0545          総合英語演習  ○    1  M・F・E・T    1  NaN  〔＊大木〕   NaN
# 182  0546          総合英語演習  ○    1  M・F・E・T  1・2  NaN  〔＊大木〕   NaN
# 183  0547          総合英語演習  ○    1  M・F・E・T  1・2  NaN  〔＊大木〕   NaN
# 238  0850  早期インターンシップ準備演習  ◎    1        T    1  NaN  〔＊斎藤〕   NaN
# 239  0853      早期インターンシップ  ◎    1        T    2  NaN  〔＊斎藤〕   NaN

# %% [markdown]
# # 最大人数

# %%
df['最大人数'].unique()
# Out:
# array([ nan, 180.,  50.])

# %%
# 最大人数がない場合は、時間割を決める際にどのように部屋を割り当てているのでしょうか。
# 前年度の教室の規模をそのまま流用している形でしょうか？
df[df['最大人数'].isnull()].head()
# Out:
#   授業コード        授業科目 必選  コマ数      ｺｰｽ 学年  ｸﾗｽ  教員名  最大人数
# 0  0001     スタディスキル  ◎    1  M・F・E・T  1  ④-1  高橋明   NaN
# 1  0002     スタディスキル  ◎    1  M・F・E・T  1  ④-2   福山   NaN
# 2  0003     スタディスキル  ◎    1  M・F・E・T  1  ④-3   福山   NaN
# 3  0004     スタディスキル  ◎    1  M・F・E・T  1  ④-4   小林   NaN
# 4  0029  （特）スタディスキル  ◎    1  M・F・E・T  2  NaN  小田切   NaN

# %% [markdown]
# # その他の疑問

# %%
# 別の疑問: -cと-dは別授業なのでしょうか？8205と8207の違いがわかりません。
# 別の疑問: 基礎力学Ⅱを再履修になったEコースの学生はどうなるのでしょうか？
df.loc[df['授業科目'].str.contains('基礎力学Ⅱ')]
# Out:
#     授業コード     授業科目 必選  コマ数    ｺｰｽ 学年  ｸﾗｽ 教員名  最大人数
# 412  8204  基礎力学Ⅱ-a  ■    1    M・F  2  NaN  南葉   NaN
# 413  8205  基礎力学Ⅱ-c  □    2  M・F・E  1   1組  山本   NaN
# 414  8206  基礎力学Ⅱ-c  □    2    M・E  1   2組  門田   NaN
# 415  8207  基礎力学Ⅱ-d  □    2  M・F・E  1  NaN  栗田   NaN

# %%
df
# Out:
#     授業コード                                  授業科目  必選  コマ数      ｺｰｽ   学年  ｸﾗｽ
# 0    0001                               スタディスキル   ◎    1  M・F・E・T    1  ④-1  \
# 1    0002                               スタディスキル   ◎    1  M・F・E・T    1  ④-2
# 2    0003                               スタディスキル   ◎    1  M・F・E・T    1  ④-3
# 3    0004                               スタディスキル   ◎    1  M・F・E・T    1  ④-4
# 4    0029                            （特）スタディスキル   ◎    1  M・F・E・T    2  NaN
# 5    0030                            （特）スタディスキル   ◎    1  M・F・E・T  1・2  NaN
# 6    0034                             情報社会と情報倫理   ○    1    M・F・E    3  NaN
# 7    0034                             情報社会と情報倫理   □    1        T    3  NaN
# 8    0035                                 技術者倫理   ○    1      M・E    3  NaN
# 9    0035                                 技術者倫理   ◎    1        F    3  NaN
# 10   0035                                 技術者倫理   □    1        T    3  NaN
# 11   0036                                 技術者倫理   ○    1      M・E    3  NaN
# 12   0036                                 技術者倫理   ◎    1        F    3  NaN
# 13   0036                                 技術者倫理   □    1        T    3  NaN
# 14   0049                                 技術者倫理   ○    1      M・E    3  NaN
# 15   0049                                 技術者倫理   ◎    1        F    3  NaN
# 16   0049                                 技術者倫理   □    1        T    3  NaN
# 17   0060                                  生命倫理   ○    1    M・F・E    3  NaN
# 18   0060                                  生命倫理   □    1        T    3  NaN
# 19   0070                                現代社会講座   ◎    1    M・F・E    1  ②-1
# 20   0071                                現代社会講座   ◎    1    M・F・E    1  ②-2
# 21   0086                             （特）現代社会講座   ◎    1    M・F・E  1・2  NaN
# 22   0087                     ｸﾞﾛｰﾊﾞﾙ・ｺﾐｭﾆｹｰｼｮﾝ   ◎    1        T    3  NaN
# 23   0088                             新聞理解表現演習Ⅰ   ◎    1        T    1  NaN
# 24   0089                             新聞理解表現演習Ⅱ   ◎    1        T    1  NaN
# 25   0090                     実践ﾌﾟﾚｾﾞﾝﾃｰｼｮﾝ・ｽｷﾙ   ◎    1        T    2  NaN
# 26   0091                             社会時事・討論演習   ◎    1        T    2  NaN
# 27   0092                               社会・経済事情   ◎    1        T    3  NaN
# 28   0093                                暮らしの経済   ○    1  M・F・E・T    2  NaN
# 29   0095                                暮らしの経済   ○    1  M・F・E・T    2  NaN
# 30   0097                                暮らしの経済   ○    1  M・F・E・T  1・2  NaN
# 31   0099                                暮らしの経済   ○    1  M・F・E・T    2  NaN
# 32   0101                                 日本国憲法   ○    1    M・F・T    2  NaN
# 33   0101                                 日本国憲法   ◎    1        E    2  NaN
# 34   0103                                 日本国憲法   ○    1    M・F・T    2  NaN
# 35   0103                                 日本国憲法   ◎    1        E    2  NaN
# 36   0105                                 日本国憲法   ○    1    M・F・T    2  NaN
# 37   0105                                 日本国憲法   ◎    1        E    2  NaN
# 38   0107                                 日本国憲法   ○    1    M・F・T  1・2  NaN
# 39   0107                                 日本国憲法   ◎    1        E  1・2  NaN
# 40   0109                                 日本国憲法   ○    1    M・F・T  1・2  NaN
# 41   0109                                 日本国憲法   ◎    1        E  1・2  NaN
# 42   0111                                 日本国憲法   ○    1    M・F・T  1・2  NaN
# 43   0111                                 日本国憲法   ◎    1        E  1・2  NaN
# 44   0113                                日本近現代史   ○    1  M・F・E・T    2  NaN
# 45   0116                                日本近現代史   ○    1  M・F・E・T    2  NaN
# 46   0117                                日本近現代史   ○    1  M・F・E・T  1･2  NaN
# 47   0119                          ﾖｰﾛｯﾊﾟの歴史と文化   ○    1  M・F・E・T    2  NaN
# 48   0121                          ﾖｰﾛｯﾊﾟの歴史と文化   ○    1  M・F・E・T  1･2  NaN
# 49   0123                             アジアの文化と社会   ○    1  M・F・E・T    2  NaN
# 50   0125                             アジアの文化と社会   ○    1  M・F・E・T    2  NaN
# 51   0127                             アジアの文化と社会   ○    1  M・F・E・T  1・2  NaN
# 52   0129                             アジアの文化と社会   ○    1  M・F・E・T  1・2  NaN
# 53   0130                               マスメディア論   ○    1  M・F・E・T    2  NaN
# 54   0131                            少子高齢化と社会問題   ○    1  M・F・E・T    2  NaN
# 55   0132                            少子高齢化と社会問題   ○    1  M・F・E・T  1・2  NaN
# 56   0133                            少子高齢化と社会問題   ○    1  M・F・E・T  1・2  NaN
# 57   0134                               マスメディア論   ○    1  M・F・E・T    2  NaN
# 58   0135                               マスメディア論   ○    1  M・F・E・T  1・2  NaN
# 59   0136                               マスメディア論   ○    1  M・F・E・T  1・2  NaN
# 60   0137                               マスメディア論   ○    1  M・F・E・T  1・2  NaN
# 61   0138                                 宗教と倫理   ○    1  M・F・E・T    2  NaN
# 62   0139                                 宗教と倫理   ○    1  M・F・E・T  1・2  NaN
# 63   0140                                 比較文化論   ○    1  M・F・E・T    2  NaN
# 64   0141                                 比較文化論   ○    1  M・F・E・T  1・2  NaN
# 65   0144                           社会参加とボランティア   ○    1  M・F・E・T    2  NaN
# 66   0145                           社会参加とボランティア   ○    1  M・F・E・T    2  NaN
# 67   0146                             国際化と異文化理解   ○    1  M・F・E・T    2  NaN
# 68   0148                             国際化と異文化理解   ○    1  M・F・E・T  1・2  NaN
# 69   0150                              現代社会の心理学   ○    1  M・F・E・T    2  NaN
# 70   0151                              現代社会の心理学   ○    1  M・F・E・T    2  NaN
# 71   0152                              現代社会の心理学   ○    1  M・F・E・T    2  NaN
# 72   0153                              現代社会の心理学   ○    1  M・F・E・T  1・2  NaN
# 73   0154                              現代社会の心理学   ○    1  M・F・E・T  1・2  NaN
# 74   0155                              現代社会の心理学   ○    1  M・F・E・T  1・2  NaN
# 75   0156                                   環境論   ○    1  M・F・E・T    2  NaN
# 76   0157                              現代社会の心理学   ○    1  M・F・E・T  1・2  NaN
# 77   0158                                   環境論   ○    1  M・F・E・T    2  NaN
# 78   0160                                   環境論   ○    1  M・F・E・T  1・2  NaN
# 79   0162                                   環境論   ○    1  M・F・E・T  1・2  NaN
# 80   0164                              人文社会科学演習   ○    2  M・F・E・T    3  NaN
# 81   0166                              人文社会科学演習   ○    2  M・F・E・T    3  NaN
# 82   0167                              人文社会科学演習   ○    2  M・F・E・T    3  NaN
# 83   0168                                    哲学   ○    1  M・F・E・T    3  NaN
# 84   0169                                    哲学   ○    1  M・F・E・T  2・3  NaN
# 85   0170                                   倫理学   ○    1  M・F・E・T    3  NaN
# 86   0172                                   倫理学   ○    1  M・F・E・T    3  NaN
# 87   0174                                    文学   ○    1  M・F・E・T    3  NaN
# 88   0175                                    文学   ○    1  M・F・E・T    3  NaN
# 89   0176                                    文学   ○    1  M・F・E・T  2・3  NaN
# 90   0177                                    文学   ○    1  M・F・E・T  2・3  NaN
# 91   0178                                   教育学   ○    1  M・F・E・T    3  NaN
# 92   0180                                   教育学   ○    1  M・F・E・T  2・3  NaN
# 93   0182                                   心理学   ○    1  M・F・E・T    3  NaN
# 94   0183                                   心理学   ○    1  M・F・E・T    3  NaN
# 95   0184                                   心理学   ○    1  M・F・E・T  2・3  NaN
# 96   0185                                   心理学   ○    1  M・F・E・T  2・3  NaN
# 97   0186                                   心理学   ○    1  M・F・E・T    3  NaN
# 98   0187                                   政治学   ○    1  M・F・E・T    3  NaN
# 99   0188                                   政治学   ○    1  M・F・E・T  2・3  NaN
# 100  0189                                   政治学   ○    1  M・F・E・T    3  NaN
# 101  0190                                   経済学   ○    1  M・F・E・T    3  NaN
# 102  0192                                   経済学   ○    1  M・F・E・T    3  NaN
# 103  0194                                   経済学   ○    1  M・F・E・T  2・3  NaN
# 104  0196                                   経済学   ○    1  M・F・E・T    3  NaN
# 105  0198                                   経済学   ○    1  M・F・E・T    3  NaN
# 106  0200                                    法学   ○    1  M・F・E・T    3  NaN
# 107  0202                                    法学   ○    1  M・F・E・T  2・3  NaN
# 108  0204                                    法学   ○    1  M・F・E・T    3  NaN
# 109  0206                                    法学   ○    1  M・F・E・T  2・3  NaN
# 110  0208                                    法学   ○    1  M・F・E・T    3  NaN
# 111  0210                                    法学   ○    1  M・F・E・T  2・3  NaN
# 112  0212                                   社会学   ○    1  M・F・E・T  2・3  NaN
# 113  0213                                   社会学   ○    1  M・F・E・T  2・3  NaN
# 114  0214                                   社会学   ○    1  M・F・E・T    3  NaN
# 115  0215                                 企業と経営   ○    1  M・F・E・T    3  NaN
# 116  0216                                 企業と経営   ○    1  M・F・E・T  2・3  NaN
# 117  0217                                 企業と経営   ○    1  M・F・E・T  2・3  NaN
# 118  0230                         健康・スポーツ科学実習Ⅰ　   ○    1    M・F・T    1  NaN
# 119  0230                         健康・スポーツ科学実習Ⅰ　   ◎    1        E    1  NaN
# 120  0232                         健康・スポーツ科学実習Ⅰ　   ○    1    M・F・T    1  NaN
# 121  0232                         健康・スポーツ科学実習Ⅰ　   ◎    1        E    1  NaN
# 122  0262                         健康・スポーツ科学実習Ⅱ　   ○    1    M・F・T    1  NaN
# 123  0262                         健康・スポーツ科学実習Ⅱ　   ◎    1        E    1  NaN
# 124  0264                         健康・スポーツ科学実習Ⅱ　   ○    1    M・F・T    1  NaN
# 125  0264                         健康・スポーツ科学実習Ⅱ　   ◎    1        E    1  NaN
# 126  0294                           レクレーションスポーツ   ○    1  M・F・E・T    2  NaN
# 127  0299                              生涯スポーツ実技   ○    1  M・F・E・T    2  NaN
# 128  0310                                   英語Ⅱ   ○    1    M・F・E    1   1組
# 129  0311                                   英語Ⅲ   ○    1    M・F・E    1   1組
# 130  0313                                   英語Ⅱ   ○    1    M・F・E    1   2組
# 131  0335                                   英語Ⅲ   ○    1    M・F・E    1   2組
# 132  0337                                   英語Ⅰ   ○    1    M・F・E    2  NaN
# 133  0341                                   英語Ⅲ   ○    1    M・F・E    1  NaN
# 134  0341                                （特）英語Ⅲ   ○    1    M・F・E    1  NaN
# 135  0342                                   英語Ⅱ   ○    1    M・F・E    1  NaN
# 136  0344                                   英語Ⅳ   ○    1    M・F・E    1  NaN
# 137  0345                                （特）英語Ⅴ   ○    1    M・F・E    2  NaN
# 138  0346                                （特）英語Ⅵ   ○    1    M・F・E    2   3組
# 139  0368                                   英語Ⅴ   〇    1    M・F・E    2   2組
# 140  0372                                   英語Ⅲ   ○    1    M・F・E    2  NaN
# 141  0373                                （特）英語Ⅲ   ○    1    M・F・E    2  NaN
# 142  0374                                   英語Ⅳ   ○    1    M・F・E    2   1組
# 143  0375                                   英語Ⅴ   ○    1    M・F・E    2   1組
# 144  0376                                   英語Ⅴ   ○    1    M・F・E    2   2組
# 145  0398                                   英語Ⅳ   ○    1    M・F・E    2   2組
# 146  0402                                （特）英語Ⅲ   ○    1    M・F・E    2  NaN
# 147  0406                                （特）英語Ⅳ   ○    1    M・F・E    2   1組
# 148  0407                                （特）英語Ⅳ   ○    1    M・F・E    2   2組
# 149  0409                                （特）英語Ⅲ   ○    1    M・F・E    2  NaN
# 150  0410                                   英語Ⅳ   ○    1    M・F・E    2  NaN
# 151  0411                                   英語Ⅴ   ○    1    M・F・E    2   1組
# 152  0412                                   英語Ⅵ   ○    1    M・F・E    2   1組
# 153  0417                                （特）英語Ⅲ   ○    1    M・F・E    2  NaN
# 154  0420                                （特）英語Ⅳ   ○    1    M・F・E    2   2組
# 155  0422                                （特）英語Ⅴ   ○    1    M・F・E    2   1組
# 156  0424                                （特）英語Ⅴ   ○    1    M・F・E    2   2組
# 157  0430                                （特）英語Ⅵ   ○    1    M・F・E    2  NaN
# 158  0431                                （特）英語Ⅳ   ○    1    M・F・E    2   3組
# 159  0444                                   英語Ⅵ   ○    1    M・F・E    2   2組
# 160  0445                                   英語Ⅲ   ○    1    M・F・E    2  NaN
# 161  0446                                   英語Ⅰ   ○    1    M・F・E    1  NaN
# 162  0447                                   英語Ⅰ   ○    1    M・F・E    1  NaN
# 163  0448                                   英語Ⅱ   ○    1    M・F・E    2  NaN
# 164  0461                                （特）英語Ⅵ   ○    1    M・F・E    2   1組
# 165  0462                                （特）英語Ⅵ   ○    1    M・F・E    2   2組
# 166  0463                                （特）英語Ⅳ   ○    1    M・F・E    2   1組
# 167  0470                            ＬｉｓｔｅｎｉｎｇⅠ   ◎    1        T    1  NaN
# 168  0471                            ＬｉｓｔｅｎｉｎｇⅡ   ◎    1        T    1  NaN
# 169  0472                            ＬｉｓｔｅｎｉｎｇⅢ   ◎    1        T    2  NaN
# 170  0473                            ＬｉｓｔｅｎｉｎｇⅣ   ◎    1        T    2  NaN
# 171  0474                              ＲｅａｄｉｎｇⅠ   ◎    1        T    1  NaN
# 172  0475                              ＲｅａｄｉｎｇⅡ   ◎    1        T    1  NaN
# 173  0476                              ＲｅａｄｉｎｇⅢ   ◎    1        T    2  NaN
# 174  0477                              ＲｅａｄｉｎｇⅣ   ◎    1        T    2  NaN
# 175  0486                               科学技術英語Ⅱ   ○    1    M・F・E    3  NaN
# 176  0486                               科学技術英語Ⅱ   ◎    1        T    3  NaN
# 177  0486                   （特）科学技術英語Ⅱ（19生以前のみ）   ◎    1        J    3  NaN
# 178  0490                               科学技術英語Ⅰ   ○    1    M・F・E    3  NaN
# 179  0490                               科学技術英語Ⅰ   ◎    1        T    3  NaN
# 180  0544                                総合英語演習   ○    1  M・F・E・T    1  NaN
# 181  0545                                総合英語演習   ○    1  M・F・E・T    1  NaN
# 182  0546                                総合英語演習   ○    1  M・F・E・T  1・2  NaN
# 183  0547                                総合英語演習   ○    1  M・F・E・T  1・2  NaN
# 184  0550                                ＴＯＥＩＣⅠ   ○    1    M・F・E    2  NaN
# 185  0554                                ＴＯＥＩＣⅠ   ○    1    M・F・E    3  NaN
# 186  0560                                ＴＯＥＩＣⅡ   ○    1    M・F・E    3  NaN
# 187  0562                                ＴＯＥＩＣⅡ   ○    1    M・F・E    3  NaN
# 188  0566             Ｒｅａｄｉｎｇ and Ｌｉｓｔｅｎｉｎｇ Ａ-Ⅰ   ◎    1        T    3  NaN
# 189  0567             Ｒｅａｄｉｎｇ and Ｌｉｓｔｅｎｉｎｇ Ａ-Ⅱ   ◎    1        T    3  NaN
# 190  0568             Ｒｅａｄｉｎｇ and Ｌｉｓｔｅｎｉｎｇ Ｂ-Ⅰ   ◎    1        T    3  NaN
# 191  0569             Ｒｅａｄｉｎｇ and Ｌｉｓｔｅｎｉｎｇ Ｂ-Ⅱ   ◎    1        T    3  NaN
# 192  0583                               日本語表現技術   ○    1  M・F・E・T    1  ②-1
# 193  0608                               日本語表現技術   ○    1  M・F・E・T    1  ②-2
# 194  0609                               日本語表現技術   ○    1  M・F・E・T    2  NaN
# 195  0610                               日本語表現技術   ○    1  M・F・E・T    2  NaN
# 196  0611                               日本語表現技術   ○    1  M・F・E・T    2  NaN
# 197  0617                               日本語表現技術   ○    1  M・F・E・T    2  NaN
# 198  0618                               日本語表現技術   ○    1  M・F・E・T    2  NaN
# 199  0619                               日本語表現技術   ○    1  M・F・E・T    2  NaN
# 200  0625                               日本語表現技術   ○    1  M・F・E・T    2  NaN
# 201  0626                               日本語表現技術   ○    1  M・F・E・T    2  NaN
# 202  0627                               日本語表現技術   ○    1  M・F・E・T    2  NaN
# 203  0637                           プレゼンテーション技術   ○    1  M・F・E・T    2  NaN
# 204  0638                           プレゼンテーション技術   ○    1  M・F・E・T    2  ②-1
# 205  0639                           プレゼンテーション技術   ○    1  M・F・E・T    2  ②-2
# 206  0640                           プレゼンテーション技術   ○    1  M・F・E・T    2  NaN
# 207  0641                           プレゼンテーション技術   ○    1  M・F・E・T    2  NaN
# 208  0642                           プレゼンテーション技術   ○    1  M・F・E・T    2  NaN
# 209  0643                           プレゼンテーション技術   ○    1  M・F・E・T    2  NaN
# 210  0644                           プレゼンテーション技術   ○    1  M・F・E・T    2  NaN
# 211  0650                           プレゼンテーション技術   ○    1  M・F・E・T    2  NaN
# 212  0651                           プレゼンテーション技術   ○    1  M・F・E・T    2  NaN
# 213  0652                           プレゼンテーション技術   ○    1  M・F・E・T    2  NaN
# 214  0653                           プレゼンテーション技術   ○    1  M・F・E・T    2  NaN
# 215  0654                           プレゼンテーション技術   ○    1  M・F・E・T    2  NaN
# 216  0656                           プレゼンテーション技術   ○    1  M・F・E・T    2  ②-1
# 217  0657                           プレゼンテーション技術   ○    1  M・F・E・T    2  ②-2
# 218  0670                              技術文章の書き方   ○    1  M・F・E・T    3  NaN
# 219  0672                              技術文章の書き方   ○    1  M・F・E・T    3  NaN
# 220  0675                              技術文章の書き方   ○    1  M・F・E・T    3  NaN
# 221  0676                              技術文章の書き方   ○    1  M・F・E・T    3  NaN
# 222  0690                               身の回りの数学   ◎    1      M・E    3   1組
# 223  0690                               身の回りの数学   ○    1      F・T    3   1組
# 224  0692                               身の回りの数学   ◎    1      M・E    3   2組
# 225  0692                               身の回りの数学   ○    1      F・T    3   2組
# 226  0694                               身の回りの数学   ◎    1      M・E    3   3組
# 227  0694                               身の回りの数学   ○    1      F・T    3   3組
# 228  0740                               実感する科学Ⅰ   ○    1  M・F・E・T    1  ③-1
# 229  0741                               実感する科学Ⅰ   ○    1  M・F・E・T    1  ③-2
# 230  0742                               実感する科学Ⅰ   ○    1  M・F・E・T    1  ③-3
# 231  0781                               実感する科学Ⅱ   ○    1  M・F・E・T    1  NaN
# 232  0790                               情報リテラシー   ◎    1    M・E・T    1  ②-1
# 233  0790                               情報リテラシー   ○    1        F    1  NaN
# 234  0792                               情報リテラシー   ◎    1    M・E・T    1  ②-2
# 235  0812                           ＡＩとデータサイエンス   ○    1  M・F・E・T    2  NaN
# 236  0820                                キャリア設計   ◎    1  M・F・E・T    1  NaN
# 237  0835                                キャリア開発   ◎    1  M・F・E・T    1  NaN
# 238  0850                        早期インターンシップ準備演習   ◎    1        T    1  NaN
# 239  0853                            早期インターンシップ   ◎    1        T    2  NaN
# 240  0950                            （留）言語と文化Ⅰ　   ○    1    M・F・E    2  NaN
# 241  0951                             （留）言語と文化Ⅱ   ○    1    M・F・E    2  NaN
# 242  0952                             （留）自己表現法Ⅰ   ○    1    M・F・E    3  NaN
# 243  0953                             （留）自己表現法Ⅱ   ○    1    M・F・E    3  NaN
# 244  0954                          （留）日本語・日本事情Ⅰ   ○    1    M・F・E    1  NaN
# 245  0955                          （留）日本語・日本事情Ⅱ   ○    1    M・F・E    1  NaN
# 246  1000                                 材料力学Ⅰ   ◎    1  M・F・E・T    1  ②-1
# 247  1001                                 材料力学Ⅰ   ◎    1  M・F・E・T    1  ②-2
# 248  1002                                 材料力学Ⅱ   ◎    1  M・F・E・T    2  ②-1
# 249  1003                                 材料力学Ⅱ   ◎    1  M・F・E・T    2  ②-2
# 250  1004                             （特）材料力学ⅡＪ   □    1        S    3  NaN
# 251  1004                    （特）材料力学ⅡＪ（19生以前のみ）   ◎    1    J・F・T    3  NaN
# 252  1005                              航空宇宙学概論Ⅰ   ◎    1        F    1  NaN
# 253  1005                              航空宇宙学概論Ⅰ   ○    1        T    1  NaN
# 254  1006                                 生産加工学   ◎    1  M・F・E・T    3  NaN
# 255  1007                                  流れ学Ⅰ   ◎    1  M・F・E・T    2  ②-1
# 256  1008                                  流れ学Ⅰ   ◎    1  M・F・E・T    2  ②-2
# 257  1009                             （特）流れ学ⅠＪ　   □    1        S    3  NaN
# 258  1009                     （特）流れ学ⅠＪ（19生以前のみ）   ◎    1    J・F・T    3  NaN
# 259  1010                                  流れ学Ⅱ   ◎    1  M・F・E・T    2  ②-1
# 260  1011                                  流れ学Ⅱ   ◎    1  M・F・E・T    2  ②-2
# 261  1012                              （特）流れ学ⅡJ   □    1        S    3  NaN
# 262  1012                     （特）流れ学ⅡJ（19生以前のみ）   ◎    1    J・F・T    3  NaN
# 263  1013                                  熱力学Ⅰ   ◎    1  M・F・E・T    2  ②-2
# 264  1014                                  熱力学Ⅰ   ◎    1  M・F・E・T    2  ②-1
# 265  1016                                  熱力学Ⅱ   ◎    1  M・F・E・T    2  ②-2
# 266  1017                                  熱力学Ⅱ   ◎    1  M・F・E・T    2  ②-1
# 267  1018                              （特）熱力学ⅡＪ   □    1        S    3  NaN
# 268  1018                     （特）熱力学ⅡＪ（19生以前のみ）   ◎    1    J・F・T    3  NaN
# 269  1020                       航空宇宙実験ﾌﾟﾛｼﾞｪｸﾄⅡ   ◎    2        F    1  NaN
# 270  1020                       航空宇宙実験ﾌﾟﾛｼﾞｪｸﾄⅡ   □    2        T    1  NaN
# 271  1021                    （特）機械力学入門（19生以前のみ）   □    1        S    3  NaN
# 272  1023                                 機械力学Ⅰ   ◎    1  M・F・E・T    2  ②-1
# 273  1024                                 機械力学Ⅰ   ◎    1  M・F・E・T    2  ②-2
# 274  1025                             （特）機械力学ⅠJ   □    1        S    3  NaN
# 275  1025                    （特）機械力学ⅠJ（19生以前のみ）   ◎    1    J・F・T    3  NaN
# 276  1026                            (特)機械力学入門Ｊ   □    1        S    3  NaN
# 277  1026                            (特)機械力学入門Ｊ   ◎    1    J・F・T    3  NaN
# 278  1027              ｴﾝｼﾞﾆｱﾘﾝｸﾞ・ﾃﾞｻﾞｲﾝと生物模倣技術   □    1        M    3  NaN
# 279  1028                                 機械力学Ⅱ   ○    1    M・F・E    2  NaN
# 280  1028                                 機械力学Ⅱ   ◎    1        T    2  NaN
# 281  1029                             （特）飛行力学入門   ◎    1        F    3  NaN
# 282  1029                    （特）飛行力学入門（19生以前のみ）   ○    1        T    3  NaN
# 283  1030                             プログラミング基礎   ◎    1    M・F・E    2  ②-1
# 284  1031                             プログラミング基礎   ◎    1    M・F・E    2  ②-2
# 285  1032                             実践プログラミング   ○    1    M・F・E    2  NaN
# 286  1033                                総合機械講座   □    1        M    3  NaN
# 287  1035                            機械及び電気工学実験   ◎    2  M・F・E・T    2  ②-1
# 288  1036                            機械及び電気工学実験   ◎    2  M・F・E・T    2  ②-2
# 289  1037                             航空宇宙学特別講義   □    2        F    3  NaN
# 290  1037                             航空宇宙学特別講義   ○    2        T    3  NaN
# 291  1038                              機械工学特別講義   ○    2    M・E・T    3  NaN
# 292  1039                     （特）機械力学Ⅰ（19生以前のみ）   □    1        S    3  NaN
# 293  1040                                 材料力学Ⅲ   ○    1      M・E    2  ②-2
# 294  1040                                 材料力学Ⅲ   ◎    1      F・T    2  ②-2
# 295  1041                                 材料力学Ⅲ   ○    1      M・E    2  ②-1
# 296  1041                                 材料力学Ⅲ   ◎    1      F・T    2  ②-1
# 297  1042                                  材料工学   ○    1      M・E    2  ②-1
# 298  1042                                材料工学　　   ◎    1      F・T    2  ②-1
# 299  1044                                  材料工学   ○    1      M・E    2  ②-2
# 300  1044                                材料工学　　   ◎    1      F・T    2  ②-2
# 301  1046                                機械工学概論   ◎    1      M・E    1  ②-1
# 302  1047                                機械工学概論   ◎    1      M・E    1  ②-2
# 303  1048                                  流体力学   ○    1    M・F・E    3  NaN
# 304  1048                                  流体力学   ◎    1        T    3  NaN
# 305  1050                                 応用熱力学   ○    1  M・F・E・T    3  NaN
# 306  1051                                機械応用実験   □    2        M    3  NaN
# 307  1051                                機械応用実験   ◎    2        F    3  NaN
# 308  1052                                  伝熱工学   ○    1    M・F・E    3  NaN
# 309  1052                                  伝熱工学   ◎    1        T    3  NaN
# 310  1052                               （特）伝熱工学   ○    1      S・F    3  NaN
# 311  1052                      （特）伝熱工学（19生以前のみ）   ◎    1      J・T    3  NaN
# 312  1054                             （特）機械力学ⅡJ   ◎    1      J・T    3  NaN
# 313  1054                    （特）機械力学ⅡJ（19生以前のみ）   ○    1        F    3  NaN
# 314  1055                              （特）機械力学Ⅱ   ○    1        S    3  NaN
# 315  1057                                  制御工学   ○    1    M・E・T    3  NaN
# 316  1057                                  制御工学   ◎    1        F    3  NaN
# 317  1059                                ロボット工学   ○    1      M・T    4  NaN
# 318  1060                                 自動車工学   ○    1    M・E・T    3  NaN
# 319  1061                                 航空機設計   □    2      F・T    3  NaN
# 320  1062                                航空宇宙工学   ○    1  M・F・E・T  3・4  NaN
# 321  1064                                  飛行力学   ○    1      F・T    3  NaN
# 322  1065                              航空宇宙学概論Ⅱ   ○    1      F・T    1  NaN
# 323  1067                             航空宇宙機構造力学   ◎    1        F    3  NaN
# 324  1067                             航空宇宙機構造力学   ○    1        T    3  NaN
# 325  1068                              航空宇宙推進工学   ○    1  M・F・E・T    3  NaN
# 326  1069                             宇宙機システム工学   ○    1      F・T    3  NaN
# 327  1070                            航空宇宙通信システム   ○    1      F・T  3・4  NaN
# 328  1071                                飛行制御概論   ○    1      F・T    2  NaN
# 329  1072                                 航空法概論   ○    1      F・T    2  NaN
# 330  1073                                機械設計法Ⅰ   ◎    1  M・F・E・T    2  ②-1
# 331  1074                                機械設計法Ⅰ   ◎    1  M・F・E・T    2  ②-2
# 332  1075                                機械設計法Ⅱ   ◎    1    M・E・T    2  ②-1
# 333  1075                                機械設計法Ⅱ   ○    1        F    2  NaN
# 334  1076                                機械設計法Ⅱ   ◎    1    M・E・T    2  ②-2
# 335  1078                                機械製図基礎   ◎    2  M・F・E・T    2  ②-1
# 336  1079                                機械製図基礎   ◎    2  M・F・E・T    2  ②-2
# 337  1082                              機械製図ユニット   ◎    2  M・F・E・T    2  ②-1
# 338  1083                              機械製図ユニット   ◎    2  M・F・E・T    2  ②-2
# 339  1084                             創造設計ユニットⅠ   □    3        M    3  NaN
# 340  1084                             創造設計ユニットⅠ   ◎    3        E    3  NaN
# 341  1085                            機械設計製図ユニット   □    2      M・T    3  NaN
# 342  1086                           機械工学プロジェクトⅠ   ◎    2      M・E    1  ②-1
# 343  1086                           機械工学プロジェクトⅠ   □    2        T    1  ②-1
# 344  1088                       航空宇宙実験ﾌﾟﾛｼﾞｪｸﾄⅠ   ◎    2        F    1  NaN
# 345  1088                       航空宇宙実験ﾌﾟﾛｼﾞｪｸﾄⅠ   □    2        T    1  NaN
# 346  1089                            航空宇宙プロジェクト   ◎    2        F    3  NaN
# 347  1090                             創造設計ユニットⅡ   □    3        M    3  NaN
# 348  1090                             創造設計ユニットⅡ   ◎    3        E    3  NaN
# 349  1092                           機械工学プロジェクトⅠ   ◎    2      M・E    1  ②-2
# 350  1092                           機械工学プロジェクトⅠ   □    2        T    1  ②-2
# 351  1095                                高速空気力学   ○    1  M・F・E・T  3・4  NaN
# 352  1096                           機械工学プロジェクトⅡ   ◎    2      M・E    1  ②-1
# 353  1096                           機械工学プロジェクトⅡ   □    2        T    1  NaN
# 354  1096                           機械工学プロジェクトⅡ   ◎    2      M・E    1  ②-1
# 355  1097                           機械工学プロジェクトⅡ   ◎    2      M・E    1  ②-2
# 356  1097                           機械工学プロジェクトⅡ   ◎    2      M・E    1  ②-2
# 357  1098                                機械力学入門   ◎    1  M・F・E・T    1  ②-1
# 358  1099                                機械力学入門   ◎    1  M・F・E・T    1  ②-2
# 359  1100                               特別専攻研究Ⅱ   □    1        T    3  NaN
# 360  1101                               卒研セミナー    ○    1      M・F    3  NaN
# 361  1102                               特別専攻研究Ⅰ   ◎    1        T    3  NaN
# 362  1103                        卒業研究Ⅱ（19生以前のみ）   ◎    1  S・J・F・T    4  NaN
# 363  1104                                  卒業研究   ◎    1    M・F・T    4  NaN
# 364  1106                       1年生機械工学特別専攻ｾﾞﾐⅠ   ◎    1        T    1  NaN
# 365  1107                       1年生機械工学特別専攻ｾﾞﾐⅡ   ◎    1        T    1  NaN
# 366  1109                       2年生機械工学特別専攻ｾﾞﾐⅠ   ◎    1        T    2  NaN
# 367  1111                       2年生機械工学特別専攻ｾﾞﾐⅡ   ◎    1        T    2  NaN
# 368  1234                              環境・エネルギー   ○    1        E    2  NaN
# 369  3339                           教育コンテンツ開発実践   ○    1        E    2  NaN
# 370  3342                           教育パフォーマンス実践   ○    1        E    2  NaN
# 371  8000                              微分積分学Ⅰ-c   □    2    M・F・E    1   1組
# 372  8001                              微分積分学Ⅰ-d   □    2    M・F・E    1   2組
# 373  8002                              微分積分学Ⅰ-d   □    2    M・F・E    1   1組
# 374  8003                              微分積分学Ⅱ-c   □    2    M・F・E    1   2組
# 375  8004                              微分積分学Ⅱ-d   □    2    M・F・E    1   2組
# 376  8005                              微分積分学Ⅱ-c   □    2    M・F・E    1   1組
# 377  8006                              微分積分学Ⅱ-d   □    2    M・F・E    1   1組
# 378  8006                              微分積分学Ⅱ-d   ◎    2        T    1  NaN
# 379  8025                              微分積分学Ⅰ-c   □    2    M・F・E    1   2組
# 380  8051                             線形代数学Ⅰ-a　   □    1    M・F・E    1   1組
# 381  8052                            線形代数学Ⅰ-a　　   □    1    M・F・E    1   2組
# 382  8053                            線形代数学Ⅰ-b　　   □    1    M・F・E    1   1組
# 383  8053                          線形代数学Ⅰ-b　　　　   ◎    1        T    1  NaN
# 384  8054                          線形代数学Ⅰ-b　　　　   □    1    M・F・E    1   2組
# 385  8055                             線形代数学Ⅱ-a　   □    1    M・F・E    1   1組
# 386  8056                            線形代数学Ⅱ-a　　   □    1    M・F・E    1   2組
# 387  8057                            線形代数学Ⅱ-b　　   □    1    M・F・E    1   1組
# 388  8057                          線形代数学Ⅱ-b　　　　   ◎    1        T    1  NaN
# 389  8058                          線形代数学Ⅱ-b　　　　   □    1    M・F・E    1   2組
# 390  8086                           （特）線形代数学Ⅰ-a   □    1    M・F・E    1  NaN
# 391  8087                           （特）線形代数学Ⅱ-a   □    1    M・F・E    2  NaN
# 392  8093                                 機械系数学   ○    1      M・E    2   2組
# 393  8094                                 機械系数学   ○    1      M・E    2   1組
# 394  8094                                 機械系数学   ◎    1        T    2  NaN
# 395  8095                                 機械系数学   ◎    1        F    2  NaN
# 396  8098                              （特）機械系数学   ○    1      M・E    2  NaN
# 397  8098                              （特）機械系数学   ◎    1      F・T    2  NaN
# 398  8102                              ベクトル解析　　   ○    1  M・F・E・T    2  NaN
# 399  8106                                フーリエ解析   ○    1  M・F・E・T    2  NaN
# 400  8110                                 確率統計Ｓ   ◎    1        T    2  NaN
# 401  8111                                  確率統計   ○    1      M・E    2  NaN
# 402  8112                                  確率統計   ○    1      M・E    2  NaN
# 403  8112                                  確率統計   ◎    1        F    2  NaN
# 404  8117                                  関数論Ⅰ   ○    1    M・F・E    2  NaN
# 405  8118                                  関数論Ⅱ   ○    1    M・F・E    2  NaN
# 406  8139                                  解析学Ⅰ   ◎    2        T    1  NaN
# 407  8200                               基礎力学Ⅰ-a   ■    1      M・F    1  NaN
# 408  8201                               基礎力学Ⅰ-c   □    2    M・F・E    1   1組
# 409  8202                               基礎力学Ⅰ-c   □    2      M・E    1   2組
# 410  8202                               基礎力学Ⅰ-c   □    2      M・E    1   2組
# 411  8203                               基礎力学Ⅰ-d   □    2    M・F・E    1  NaN
# 412  8204                               基礎力学Ⅱ-a   ■    1      M・F    2  NaN
# 413  8205                               基礎力学Ⅱ-c   □    2    M・F・E    1   1組
# 414  8206                               基礎力学Ⅱ-c   □    2      M・E    1   2組
# 415  8207                               基礎力学Ⅱ-d   □    2    M・F・E    1  NaN
# 416  8236                             基礎電磁気学Ⅰ-a   □    1    M・F・E    1   1組
# 417  8237                             基礎電磁気学Ⅰ-a   □    1    M・F・E    1   2組
# 418  8238                             基礎電磁気学Ⅱ-b   □    1    M・F・E    2  NaN
# 419  8239                             基礎電磁気学Ⅱ-a   □    1    M・F・E    2  ②-1
# 420  8240                             基礎電磁気学Ⅱ-a   □    1    M・F・E    2  ②-2
# 421  8241                             基礎電磁気学Ⅰ-b   □    1    M・F・E    1  NaN
# 422  8256                          （特）基礎電磁気学Ⅰ-a   □    1    M・F・E    2  NaN
# 423  8256                 （特）基礎電磁気学Ⅰ-a（19生以前のみ）   □    1      S・J    2  NaN
# 424  8259                          （特）基礎電磁気学Ⅱ-a   □    1    M・F・E    2  NaN
# 425  8259                          （特）基礎電磁気学Ⅱ-a   □    1      S・J    2  NaN
# 426  8265                                 振動と波動   ○    1    M・E・T    2  NaN
# 427  8268                               熱・統計物理学   ○    1    M・E・T    3  NaN
# 428  8270                                  量子物理   ○    1    M・E・T    3  NaN
# 429  8275                                  物理学Ａ   ◎    2        T    1  NaN
# 430  8279                                  物理学Ｃ   ◎    1        T    2  NaN
# 431  8281                                  物理学Ｄ   ◎    1        T    2  NaN
# 432  8282                                  物理学Ｂ   ◎    2        T    1  NaN
# 433  8285                        物理・化学ユニットプログラム   ◎    2  M・F・E・T    1  ②-1
# 434  8285                        物理・化学ユニットプログラム   ◎    2  M・F・E・T    1  ②-1
# 435  8286                        物理・化学ユニットプログラム   ◎    2  M・F・E・T    1  ②-2
# 436  8400                               基礎化学Ⅰ-a   ○    1    M・F・E    1  NaN
# 437  8406                               基礎化学Ⅱ-a   ○    1      M・E    1  NaN
# 438  8413                                 基礎生物学   ○    1      M・E    2  NaN
# 439  8416                                生物学概論Ⅰ   ○    1      M・E    1  NaN
# 440  8418                                生物学概論Ⅱ   ○    1      M・E    1  NaN
# 441  8421                                 地学概論Ⅰ   ○    1    M・E・T    2  NaN
# 442  8423                                 地学概論Ⅱ   ○    1    M・E・T    2  NaN
# 443  8440                                   化学Ａ   ○    1        T    1  NaN
# 444  8443                                   化学Ｂ   ○    1        T    1  NaN
# 445  8445                              ライフサイエンス   ○    1        T    1  NaN
# 446  9000                                  教職概論   ◎    1      nan    1  NaN
# 447  9001                                  教職概論   ◎    1      nan    1  NaN
# 448  9002                              学校と教育の歴史   ◎    1      nan    1  NaN
# 449  9004                                 教育心理学   ◎    1      nan    1  NaN
# 450  9005                                 教育行政論   ◎    1      nan    2  NaN
# 451  9006                                 教育課程論   ◎    1      nan    3  NaN
# 452  9007                               工業科教育法Ⅰ   ○    1        E    3  NaN
# 453  9007                               工業科教育法Ⅰ   ◎    1      nan    3  NaN
# 454  9008                               工業科教育法Ⅱ   ○    1        E    3  NaN
# 455  9008                               工業科教育法Ⅱ   ◎    1      nan    3  NaN
# 456  9013                               数学科教育法Ⅲ   ◎    1      nan    3  NaN
# 457  9014                               技術科教育法Ⅲ   ○    1        E    3  NaN
# 458  9014                               技術科教育法Ⅲ   ◎    1      nan    3  NaN
# 459  9015                               数学科教育法Ⅰ   ◎    1      nan    2  NaN
# 460  9016                               数学科教育法Ⅱ   ◎    1      nan    2  NaN
# 461  9017                             生徒指導と進路指導   ◎    1      nan    2  NaN
# 462  9018                              特別支援教育概論   ◎    1      nan    2  NaN
# 463  9019                               技術科教育法Ⅰ   ○    1        E    2  NaN
# 464  9019                               技術科教育法Ⅰ   ◎    1      nan    2  NaN
# 465  9020                               技術科教育法Ⅱ   ○    1        E    2  NaN
# 466  9020                               技術科教育法Ⅱ   ◎    1      nan    2  NaN
# 467  9021                       総合的な学習の時間の理論と実践   ◎    1      nan    2  NaN
# 468  9023                            道徳教育の理論と実践   ◎    1      nan    3  NaN
# 469  9024                              特別活動の指導法   ◎    1      nan    2  NaN
# 470  9025                              教育の方法と技術   ◎    1      nan    3  NaN
# 471  9026                               数学科教育法Ⅳ   ◎    1      nan    3  NaN
# 472  9027                               技術科教育法Ⅳ   ○    1        E    3  NaN
# 473  9027                               技術科教育法Ⅳ   ◎    1      nan    3  NaN
# 474  9028                                  教育相談   ◎    1      nan    3  NaN
# 475  9032                                教職実践演習   ◎    1      nan    4  NaN
# 476  9034                                  工業概論   ◎    1        E  1・2  NaN
# 477  9034                                  工業概論   ◎    1      nan    1  NaN
# 478  9035                                 職業指導Ⅰ   ◎    1        E    3  NaN
# 479  9035                                 職業指導Ⅰ   ◎    1      nan    3  NaN
# 480  9036                                 職業指導Ⅱ   ○    1        E    3  NaN
# 481  9036                                 職業指導Ⅱ   ○    1      nan    3  NaN
# 482  9039                                   幾何学   ◎    1      nan    2  NaN
# 483  9040                                   代数学   ○    1      nan    3  NaN
# 484  9041                                   統計学   ○    1      nan    3  NaN
# 485  9042                                木材加工概論   ◎    1        E  1・2  NaN
# 486  9042                                木材加工概論   ◎    1      nan    1  NaN
# 487  9043                                金属加工概論   ◎    1        E  1・2  NaN
# 488  9043                                金属加工概論   ◎    1      nan    1  NaN
# 489  9045                                  電気概論   ◎    1        E  1・2  NaN
# 490  9045                                  電気概論   ◎    1      nan    1  NaN
# 491  9046                                  栽培概論   ○    1        E  1・2  NaN
# 492  9046                                  栽培概論   ◎    1      nan    1  NaN
# 493  9047                          情報とｺﾝﾋﾟｭｰﾀ概論   ○    1        E  1・2  NaN
# 494  9047                          情報とｺﾝﾋﾟｭｰﾀ概論   ◎    1      nan    1  NaN
# 495  9051                                 教育実習Ⅰ   ◎    1      nan    4  NaN
# 496  9052                                 教育実習Ⅱ   ◎    1      nan    4  NaN
# 497  9201                       Stop the CO2 入門   ○    1      M・E    1  NaN
# 498  9202                Stop the CO2 ﾌﾟﾛｼﾞｪｸﾄⅠ   ○    1      M・E    1  NaN
# 499  9203                Stop the CO2 ﾌﾟﾛｼﾞｪｸﾄⅡ   ○    1      M・E    2  NaN
# 500  9204                      Stop the CO2 最前線   ○    1      M・E    2  NaN
# 501  9205                             環境と新エネルギー   ○    1      M・E    3  NaN
# 502  9207                Stop the CO2 ﾌﾟﾛｼﾞｪｸﾄⅢ   ○    1      M・E    3  NaN
# 503  0505                                  英会話Ⅰ  ○◎    1  M・F・E・T  1・2  NaN
# 504  0523                                  英会話Ⅰ  ○◎    1  M・F・E・T  1・2  NaN
# 505  0520                                  英会話Ⅱ  ○◎    1  M・F・E・T  1・2  NaN
# 506  0525                                  英会話Ⅱ  ○◎    1  M・F・E・T  1・2  NaN
# 507  1113  Academic English for Global Leader Ⅰ   ○    1        F    1  NaN
# 508  1115  Academic English for Global Leader Ⅲ   ○    1        F    2  NaN
# 509  1114  Academic English for Global Leader Ⅱ   ○    1        F    1  NaN
# 510  1116  Academic English for Global Leader Ⅳ   ○    1        F    2  NaN
#
#                                      教員名   最大人数
# 0                                    高橋明    NaN
# 1                                     福山    NaN
# 2                                     福山    NaN
# 3                                     小林    NaN
# 4                                    小田切    NaN
# 5                                    小田切    NaN
# 6                                     三浦    NaN
# 7                                     三浦    NaN
# 8                                     中山    NaN
# 9                                     中山    NaN
# 10                                    中山    NaN
# 11                                    石田    NaN
# 12                                    石田    NaN
# 13                                    石田    NaN
# 14                                    上野    NaN
# 15                                    上野    NaN
# 16                                    上野    NaN
# 17                                     楠    NaN
# 18                                     楠    NaN
# 19             ＊三浦・師玉真・佐藤史・多田・中畑・山田陽・山本崇    NaN
# 20             ＊三浦・師玉真・佐藤史・多田・中畑・山田陽・山本崇    NaN
# 21      〔＊三浦〕　師玉真・山本聡・佐藤史・小田切・山田陽・山本崇・中畑    NaN
# 22                                  ﾑﾙｱｶ    NaN
# 23                                 〔＊師玉〕    NaN
# 24                                 〔＊師玉〕    NaN
# 25                                   師玉真    NaN
# 26                              ＊師玉真・小田切    NaN
# 27                               ＊伊藤勝・冨澤    NaN
# 28                                    室井  180.0
# 29                                    室井  180.0
# 30                                   山本崇  180.0
# 31                                    室井  180.0
# 32                                    多田  180.0
# 33                                    多田  180.0
# 34                                   山本聡  180.0
# 35                                   山本聡  180.0
# 36                                    渡辺  180.0
# 37                                    渡辺  180.0
# 38                                    多田  180.0
# 39                                    多田  180.0
# 40                                   山本聡  180.0
# 41                                   山本聡  180.0
# 42                                    多田  180.0
# 43                                    多田  180.0
# 44                                    荒船  180.0
# 45                                    荒船  180.0
# 46                                   佐々木  180.0
# 47                                    竹村  180.0
# 48                                    竹村  180.0
# 49                                     趙  180.0
# 50                                     趙  180.0
# 51                                     趙  180.0
# 52                                     趙  180.0
# 53                                    三浦  180.0
# 54                                    三浦  180.0
# 55                                    三浦  180.0
# 56                                    三浦  180.0
# 57                                    三浦  180.0
# 58                                    三浦  180.0
# 59                                     楠  180.0
# 60                                    三浦  180.0
# 61                                    中畑  180.0
# 62                                    中畑  180.0
# 63                                   師玉真  180.0
# 64                                   師玉真  180.0
# 65                                    於保  180.0
# 66                                    於保  180.0
# 67                                    義澤  180.0
# 68                                    義澤  180.0
# 69                                    山崎  180.0
# 70                                    山崎  180.0
# 71                                   佐藤史  180.0
# 72                                    鍋倉  180.0
# 73                                    鍋倉  180.0
# 74                                    鍋倉  180.0
# 75                                    兼頭  180.0
# 76                                    鍋倉  180.0
# 77                                    兼頭  180.0
# 78                                    兼頭  180.0
# 79                                    兼頭  180.0
# 80                                    三浦  180.0
# 81                                    田辺  180.0
# 82                                   師玉真  180.0
# 83                                    比嘉  180.0
# 84                                    中畑  180.0
# 85                                   高橋明  180.0
# 86                                   高橋明  180.0
# 87                                     泉  180.0
# 88                                   師玉真  180.0
# 89                                     泉  180.0
# 90                                   師玉真  180.0
# 91                                ﾊｽｹﾞﾚﾙ  180.0
# 92                                    田辺  180.0
# 93                                    三橋  180.0
# 94                                    三橋  180.0
# 95                                   佐藤史  180.0
# 96                                    山崎  180.0
# 97                                   佐藤史  180.0
# 98                                   山田博  180.0
# 99                                   山田陽  180.0
# 100                                  山田博  180.0
# 101                                   室井  180.0
# 102                                  山本崇  180.0
# 103                                  山本崇  180.0
# 104                                   室井  180.0
# 105                                   室井  180.0
# 106                                   渡辺  180.0
# 107                                  山本聡  180.0
# 108                                  山本聡  180.0
# 109                                   多田  180.0
# 110                                  山本聡  180.0
# 111                                  山本聡  180.0
# 112                                   三浦  180.0
# 113                                  小田切  180.0
# 114                                   三浦  180.0
# 115                                   高坂  180.0
# 116                                   高坂  180.0
# 117                                   高坂  180.0
# 118                         〔＊高嶋〕　勝浦・松本剛    NaN
# 119                         〔＊高嶋〕　勝浦・松本剛    NaN
# 120                         〔＊高嶋〕　勝浦・松本剛    NaN
# 121                         〔＊高嶋〕　勝浦・松本剛    NaN
# 122                             〔＊高嶋〕　岩崎    NaN
# 123                             〔＊高嶋〕　岩崎    NaN
# 124                             〔＊高嶋〕　岩崎    NaN
# 125                             〔＊高嶋〕　岩崎    NaN
# 126                            〔＊高嶋〕　松本彰    NaN
# 127                             〔＊高嶋〕　戸松    NaN
# 128                                   浅川    NaN
# 129                                   町田    NaN
# 130                                   宮城    NaN
# 131                                   山本    NaN
# 132                                   大木    NaN
# 133                                   山本    NaN
# 134                                   山本    NaN
# 135                                   岩本    NaN
# 136                                   浅川    NaN
# 137                                   大平    NaN
# 138                                   山本    NaN
# 139                                   大木    NaN
# 140                                   大木    NaN
# 141                                   町田    NaN
# 142                                   岩本    NaN
# 143                                   浅川    NaN
# 144                                   山本    NaN
# 145                                   大木    NaN
# 146                                   浅川    NaN
# 147                                   天谷    NaN
# 148                                   大平    NaN
# 149                                   岩本    NaN
# ...
# 191                                   河野    NaN
# 192                                   新谷    NaN
# 193                                    Ｄ    NaN
# 194                                  山本崇    NaN
# 195                                   福山    NaN
# 196                                  山田陽    NaN
# 197                                   松下    NaN
# 198                                  山田陽    NaN
# 199                                   福山    NaN
# 200                                   福山    NaN
# 201                                  山田陽    NaN
# 202                                   松下    NaN
# 203                                   牛膓    NaN
# 204                                   室井    NaN
# 205                                   竹村    NaN
# 206                                   松下    NaN
# 207                                   福山    NaN
# 208                                   田口    NaN
# 209                                   小林    NaN
# 210                                  小田切    NaN
# 211                                  師玉真    NaN
# 212                                   小林    NaN
# 213                                  師玉真    NaN
# 214                                  小田切    NaN
# 215                                  山本崇    NaN
# 216                                  師玉真    NaN
# 217                                   竹村    NaN
# 218                                   池川   50.0
# 219                                   池川   50.0
# 220                                   池川   50.0
# 221                                   池川   50.0
# 222                                   菊地    NaN
# 223                                   菊地    NaN
# 224                                   小机    NaN
# 225                                   小机    NaN
# 226                                  神谷亮    NaN
# 227                                  神谷亮    NaN
# 228                                   南葉    NaN
# 229                                   兒玉    NaN
# 230                                   熊谷    NaN
# 231                                   格和    NaN
# 232                                   小机    NaN
# 233                                   小机    NaN
# 234                                   熊谷    NaN
# 235  ＊納富・高取・杉村・三枝亮・宮崎・村田・臼杵・鈴木聡・塩野・須藤・前田    NaN
# 236                         ＊金井・広井・若杉・中尾    NaN
# 237                           ＊金井・瑞慶覧・前田    NaN
# 238                                〔＊斎藤〕    NaN
# 239                                〔＊斎藤〕    NaN
# 240                                  師玉礼    NaN
# 241                                   江連    NaN
# 242                                  師玉礼    NaN
# 243                                   江連    NaN
# 244                                  師玉礼    NaN
# 245                                   江連    NaN
# 246                                   吉岡    NaN
# 247                                  高橋一    NaN
# 248                                   熊谷    NaN
# 249                                   渡部    NaN
# 250                                   渡部    NaN
# 251                                   渡部    NaN
# 252                               ＊照井・中根    NaN
# 253                               ＊照井・中根    NaN
# 254                                   今井    NaN
# 255                                   萩野    NaN
# 256                                   木村    NaN
# 257                                   木村    NaN
# 258                                   木村    NaN
# 259                                   熊谷    NaN
# 260                                  木村茂    NaN
# 261                                  木村茂    NaN
# 262                                  木村茂    NaN
# 263                                    林    NaN
# 264                                  佐藤智    NaN
# 265                                    林    NaN
# 266                                  佐藤智    NaN
# 267                                    林    NaN
# 268                                    林    NaN
# 269                            ＊水野・丸山・小池    NaN
# 270                            ＊水野・丸山・小池    NaN
# 271                                   小机    NaN
# 272                                   川島    NaN
# 273                                   吉川    NaN
# 274                                   小机    NaN
# 275                                   小机    NaN
# 276                                   川島    NaN
# 277                                   川島    NaN
# 278                   ＊今井・熊谷・長尾・髙村・酒井・高取    NaN
# 279                                   照井    NaN
# 280                                   照井    NaN
# 281                               ＊照井・中根    NaN
# 282                               ＊照井・中根    NaN
# 283                                   有川    NaN
# 284                                   吉川    NaN
# 285                                   有川    NaN
# 286                         ＊今井・小机・渡部・萩野    NaN
# 287              ＊川島・佐藤智・中根・林・渡部・熊谷・山中・Ａ    NaN
# 288        ＊川島・高石・木村茂・林・吉岡・吉川・根本・山中・大場・Ａ    NaN
# 289                  ＊照井・渡邉・稲谷・杉本・三桝・佐藤昌    NaN
# 290                  ＊照井・渡邉・稲谷・杉本・三桝・佐藤昌    NaN
# 291                 ＊木村茂・渡邉・稲谷・杉本・三桝・佐藤昌    NaN
# 292                                   小机    NaN
# 293                                  高橋一    NaN
# 294                                  高橋一    NaN
# 295                                   渡部    NaN
# 296                                   渡部    NaN
# 297                                   大場    NaN
# 298                                   大場    NaN
# 299                                   大場    NaN
# 300                                   大場    NaN
# 301                             ＊林・M科全教員    NaN
# 302                             ＊林・M科全教員    NaN
# 303                                  木村茂    NaN
# 304                                  木村茂    NaN
# 305                                   高石    NaN
# 306                ＊川島・高石・有川・中根・渡部・水野・萩野    NaN
# 307                ＊川島・高石・有川・中根・渡部・水野・萩野    NaN
# 308                                   高石    NaN
# 309                                   高石    NaN
# 310                                   高石    NaN
# 311                                   高石    NaN
# 312                                   川島    NaN
# 313                                   川島    NaN
# 314                                   川島    NaN
# 315                                   小机    NaN
# 316                                   小机    NaN
# 317                                   有川    NaN
# 318                                  高橋篤    NaN
# 319                                   酒田    NaN
# 320                                   山田    NaN
# 321                                   照井    NaN
# 322                         ＊中根・照井・栗田・田中    NaN
# 323                                   渡部    NaN
# 324                                   渡部    NaN
# 325                                   西澤    NaN
# 326                               ＊照井・南部    NaN
# 327                                   田嶋    NaN
# 328                                   丸山    NaN
# 329                                   丸山    NaN
# 330                                  高橋一    NaN
# 331                                  木村南    NaN
# 332                                   水野    NaN
# 333                                   水野    NaN
# 334                                   吉川    NaN
# 335                    ＊佐藤智・熊谷・萩野・木村南・小池    NaN
# 336                    ＊佐藤智・熊谷・萩野・木村南・小池    NaN
# 337                  ＊佐藤智・萩野・水野・吉川・熊谷・小池    NaN
# 338                  ＊佐藤智・萩野・水野・吉川・熊谷・小池    NaN
# 339                         ＊今井・有川・根本・吉岡    NaN
# 340                         ＊今井・有川・根本・吉岡    NaN
# 341                               ＊水野・吉川    NaN
# 342                             ＊林・吉岡・吉川    NaN
# 343                             ＊林・吉岡・吉川    NaN
# 344                               ＊水野・中根    NaN
# 345                               ＊水野・中根    NaN
# 346                               ＊照井・田中    NaN
# 347                         ＊有川・今井・根本・吉岡    NaN
# 348                         ＊有川・今井・根本・吉岡    NaN
# 349                             ＊林・中根・吉川    NaN
# 350                             ＊林・中根・吉川    NaN
# 351                                   中根    NaN
# 352                                  NaN    NaN
# 353                         ＊林・佐藤智・熊谷・小池    NaN
# 354                         ＊林・佐藤智・熊谷・小池    NaN
# 355                                  NaN    NaN
# 356                         ＊林・佐藤智・熊谷・小池    NaN
# 357                                   川島    NaN
# 358                                   吉川    NaN
# 359                                   ＊林    NaN
# 360                                  ＊小机    NaN
# 361                                   ＊林    NaN
# 362                                  ＊中根    NaN
# 363                                  ＊中根    NaN
# 364                             ＊林・M科全教員    NaN
# 365                                   ＊林    NaN
# 366                                  佐藤智    NaN
# 367                                   川島    NaN
# 368                                  瑞慶覧    NaN
# 369                                  佐藤智    NaN
# 370                             ＊山本聡・宇田川    NaN
# 371                                   野井    NaN
# 372                                  神谷亮    NaN
# 373                                  鈴木芳    NaN
# 374                                   土谷    NaN
# 375                                   菊地    NaN
# 376                                  神谷亮    NaN
# 377                                  鈴木芳    NaN
# 378                                  鈴木芳    NaN
# 379                                   菊地    NaN
# 380                                ﾗｻﾞﾌｨ    NaN
# 381                                   米田    NaN
# 382                                   吉田    NaN
# 383                                   吉田    NaN
# 384                                  神谷亮    NaN
# 385                                   沼田    NaN
# 386                                   米田    NaN
# 387                                   米田    NaN
# 388                                   米田    NaN
# 389                                  神谷亮    NaN
# 390                                  神谷亮    NaN
# 391                                   谷戸    NaN
# 392                                  神谷亮    NaN
# 393                                   土谷    NaN
# 394                                   土谷    NaN
# 395                                   沼田    NaN
# 396                                   土谷    NaN
# 397                                   土谷    NaN
# 398                                   後藤    NaN
# 399                                   田鎖    NaN
# 400                                   竹田    NaN
# 401                                   竹田    NaN
# 402                                   竹田    NaN
# 403                                   竹田    NaN
# 404                                   後藤    NaN
# 405                                   藤森    NaN
# 406                                  鈴木芳    NaN
# 407                                  佐藤航    NaN
# 408                                   山本    NaN
# 409                                   門田    NaN
# 410                                   門田    NaN
# 411                                   栗田    NaN
# 412                                   南葉    NaN
# 413                                   山本    NaN
# 414                                   門田    NaN
# 415                                   栗田    NaN
# 416                                   門田    NaN
# 417                                   栗田    NaN
# 418                                  高橋正    NaN
# 419                                   格和    NaN
# 420                                   南葉    NaN
# 421                                    関    NaN
# 422                                   松村    NaN
# 423                                   松村    NaN
# 424                                   松村    NaN
# 425                                   松村    NaN
# 426                                   高須    NaN
# 427                                   高須    NaN
# 428                                   高須    NaN
# 429                                   山本    NaN
# 430                                   神谷    NaN
# 431                                   栗田    NaN
# 432                                   栗田    NaN
# 433             ＊石綿・山本・池田・高須・渡辺・兒玉・押鐘・鵜川    NaN
# 434    〔＊石綿〕　門田・格和・南葉・高須・渡辺・兒玉・押鐘・五十嵐・大益    NaN
# 435    〔＊石綿〕　門田・格和・南葉・高須・渡辺・兒玉・押鐘・五十嵐・大益    NaN
# 436                                  五十嵐    NaN
# 437                                   藤村    NaN
# 438                                   新井    NaN
# 439                                   新井    NaN
# 440                                   新井    NaN
# 441                                  高橋典    NaN
# 442                                  高橋典    NaN
# 443                                   藤村    NaN
# 444                                   藤村    NaN
# 445                                   新井    NaN
# 446                    ＊山本聡・門田・田辺・佐藤史・神谷    NaN
# 447                    ＊山本聡・門田・田辺・佐藤史・神谷    NaN
# 448                                   田辺    NaN
# 449                                  佐藤史    NaN
# 450                                  山本聡    NaN
# 451                                   田辺    NaN
# 452                                   塩﨑    NaN
# 453                                   塩﨑    NaN
# 454                                   塩﨑    NaN
# 455                                   塩﨑    NaN
# 456                                   毛利    NaN
# 457                                  佐藤智    NaN
# 458                                  佐藤智    NaN
# 459                                   毛利    NaN
# 460                                   川崎    NaN
# 461                                  佐藤史    NaN
# 462                                   松鹿    NaN
# 463                                   門田    NaN
# 464                                   門田    NaN
# 465                                   門田    NaN
# 466                                   門田    NaN
# 467                                   田辺    NaN
# 468                                  山本聡    NaN
# 469                                  山本明    NaN
# 470                               ＊田辺・門田    NaN
# 471                                   川崎    NaN
# 472                                   門田    NaN
# 473                                   門田    NaN
# 474                                  佐藤史    NaN
# 475                       ＊田辺・山本聡・門田・佐藤史    NaN
# 476                   ＊門田・吉野・三栖・兒玉・小池・千葉    NaN
# 477                   ＊門田・吉野・三栖・兒玉・小池・千葉    NaN
# 478                                   塩﨑    NaN
# 479                                   塩﨑    NaN
# 480                                   塩﨑    NaN
# 481                                   塩﨑    NaN
# 482                                   谷戸    NaN
# 483                                   沼田    NaN
# 484                                   竹田    NaN
# 485                                   門田    NaN
# 486                                   門田    NaN
# 487                                   門田    NaN
# 488                                   門田    NaN
# 489                                   端山    NaN
# 490                                   端山    NaN
# 491                                   石塚    NaN
# 492                                   石塚    NaN
# 493                                   吉野    NaN
# 494                                   吉野    NaN
# 495                       ＊田辺・山本聡・門田・佐藤史    NaN
# 496                       ＊田辺・山本聡・門田・佐藤史    NaN
# 497         ＊今井・板子・齋藤・納富・塩川・河原崎・金井・飯田・原島    NaN
# 498                               ＊今井・板子    NaN
# 499                         ＊今井・齋藤・金井・飯田    NaN
# 500                                  ＊今井    NaN
# 501                               ＊板子・今井    NaN
# 502                               ＊今井・板子    NaN
# 503                                   大木    NaN
# 504                                   大木    NaN
# 505                                   大木    NaN
# 506                                   大木    NaN
# 507                                  NaN    NaN
# 508                                  NaN    NaN
# 509                                  NaN    NaN
# 510                                  NaN    NaN
